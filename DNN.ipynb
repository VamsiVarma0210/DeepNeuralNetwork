# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
 np.random.seed(0)

# %%
n_pts = 500
X,y = datasets.make_moons(n_samples=n_pts, random_state=123,noise=0.1)

# %%
plt.scatter(X[y==0,0],X[y==0,1])
plt.scatter(X[y==1,0],X[y==1,1])

# %%
model =Sequential()
model.add(Dense(4,input_shape = (2,),activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))
model.compile(Adam(learning_rate=0.01),'binary_crossentropy',metrics=['accuracy'])

# %%
h = model.fit(x=X,y=y,verbose = 1, batch_size=20,epochs=100,shuffle='true')
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2133 - accuracy: 0.8940
# Epoch 2/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2105 - accuracy: 0.8960
# Epoch 3/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2085 - accuracy: 0.8980
# Epoch 4/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.8980
# Epoch 5/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.9020
# Epoch 6/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1993 - accuracy: 0.9100
# Epoch 7/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1923 - accuracy: 0.9120
# Epoch 8/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9180
# Epoch 9/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.9160
# Epoch 10/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1841 - accuracy: 0.9240
# Epoch 11/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1787 - accuracy: 0.9280
# Epoch 12/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1752 - accuracy: 0.9280
# Epoch 13/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1728 - accuracy: 0.9340
# Epoch 14/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1681 - accuracy: 0.9340
# Epoch 15/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1640 - accuracy: 0.9400
# Epoch 16/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1601 - accuracy: 0.9400
# Epoch 17/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1576 - accuracy: 0.9420
# Epoch 18/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1535 - accuracy: 0.9420
# Epoch 19/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9420
# Epoch 20/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1470 - accuracy: 0.9420
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1430 - accuracy: 0.9440
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1400 - accuracy: 0.9480
# Epoch 23/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1365 - accuracy: 0.9460
# Epoch 24/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1337 - accuracy: 0.9480
# Epoch 25/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1315 - accuracy: 0.9500
# Epoch 26/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1277 - accuracy: 0.9480
# Epoch 27/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1249 - accuracy: 0.9520
# Epoch 28/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9520
# Epoch 29/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1197 - accuracy: 0.9600
# Epoch 30/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1179 - accuracy: 0.9540
# Epoch 31/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1165 - accuracy: 0.9640
# Epoch 32/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1117 - accuracy: 0.9580
# Epoch 33/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9620
# Epoch 34/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1071 - accuracy: 0.9620
# Epoch 35/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.9580
# Epoch 36/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.9620
# Epoch 37/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9700
# Epoch 38/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0981 - accuracy: 0.9700
# Epoch 39/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0968 - accuracy: 0.9640
# Epoch 40/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9720
# Epoch 41/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9720
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0902 - accuracy: 0.9720
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9720
# Epoch 44/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0869 - accuracy: 0.9740
# Epoch 45/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 0.9780
# Epoch 46/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9780
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9800
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9800
# Epoch 49/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0778 - accuracy: 0.9840
# Epoch 50/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 0.9840
# Epoch 51/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9840
# Epoch 52/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0735 - accuracy: 0.9840
# Epoch 53/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0720 - accuracy: 0.9860
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9840
# Epoch 55/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 0.9860
# Epoch 56/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0679 - accuracy: 0.9860
# Epoch 57/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0663 - accuracy: 0.9900
# Epoch 58/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0648 - accuracy: 0.9900
# Epoch 59/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0639 - accuracy: 0.9900
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9920
# Epoch 61/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0611 - accuracy: 0.9920
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 0.9920
# Epoch 63/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0589 - accuracy: 0.9920
# Epoch 64/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0581 - accuracy: 0.9940
# Epoch 65/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 0.9920
# Epoch 66/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0556 - accuracy: 0.9920
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9920
# Epoch 68/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9940
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 0.9920
# Epoch 70/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 0.9940
# Epoch 71/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0503 - accuracy: 0.9960
# Epoch 72/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0495 - accuracy: 0.9960
# Epoch 73/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9960
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9960
# Epoch 75/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 0.9980
# Epoch 76/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0458 - accuracy: 0.9980
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9980
# Epoch 78/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0442 - accuracy: 0.9980
# Epoch 79/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 0.9960
# Epoch 80/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0427 - accuracy: 0.9980
# Epoch 81/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0420 - accuracy: 0.9980
# Epoch 82/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 0.9980
# Epoch 83/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0410 - accuracy: 0.9960
# Epoch 84/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9980
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9980
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9980
# Epoch 87/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 0.9980
# Epoch 88/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.9980
# Epoch 89/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9980
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9980
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9980
# Epoch 94/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 1.0000

# %%
plt.plot(h.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.title('accuracy')
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.plot(h.history['loss'])
plt.xlabel('epoch')
plt.legend(['loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundary(X, y, model):
   x_span = np.linspace(min(X[:,0]) - 0.25, max(X[:,0]) + 0.25)
   y_span = np.linspace(min(X[:,1]) - 0.25, max(X[:,1]) + 0.25)
   xx , yy = np.meshgrid(x_span,y_span)
   xx_,yy_ = xx.ravel(),yy.ravel()
   grid = np.c_[xx_,yy_]
   pred_func = model.predict(grid)
   z = pred_func.reshape(xx.shape)
   plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])
x = 0.1
y = 0
 
 
point = np.array([[x, y]])
prediction = model.predict(point)
plt.plot([x], [y], marker='o', markersize=10, color="red")
print("prediction is: ",prediction)
# Out:
# prediction is:  [[0.9730688]]
